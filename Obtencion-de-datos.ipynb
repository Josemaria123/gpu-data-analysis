# %%
import requests
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
import requests

session = requests.Session()

# El yield agrega a una lista las responses que va capturando. Es diferente al return porque no retorna un solo valor
# Luego hago un loop sobre esa lista y agrego los datos a un dataframe
def get_items_pages():
  url = "https://publicapi.solotodo.com/products/browse/?ordering=discount&websites=2&categories=2&exclude_refurbished=true&stores=1085&stores=30&stores=3&stores=4253&stores=4913&stores=279&stores=128&stores=920&stores=5739&stores=2570&stores=4418&stores=4847&stores=1712&stores=4&stores=722&stores=5771&stores=788&stores=2603&stores=3758&stores=201&stores=398&stores=397&stores=755&stores=3626&stores=4056&stores=31&stores=61&stores=193&stores=7&stores=5705&stores=1052&stores=5639&stores=4187&stores=3164&stores=656&stores=3131&stores=16&stores=426&stores=261&stores=4979&stores=4451&stores=1911&stores=88&stores=3791&stores=1580&stores=283&stores=172&stores=38&stores=2801&stores=559&stores=9&stores=326&stores=4682&stores=2735&stores=4484&stores=1976&stores=2240&stores=1217&stores=1448&stores=1811&stores=3692&stores=393&stores=232&stores=5573&stores=87&stores=27&stores=281&stores=4287&stores=56&stores=1283&stores=1845&stores=2967&stores=4814&stores=292&stores=5540&stores=5&stores=524&stores=199&stores=43&stores=4154&stores=228&stores=294&stores=23&stores=290&stores=392&stores=887&stores=260&stores=225&stores=4583&stores=3395&stores=265&stores=287&stores=3362&stores=37&stores=118&stores=5078&stores=39&stores=5144&stores=2339&stores=921&stores=257&stores=5738&stores=266&stores=3263&stores=986&stores=3890&stores=4880&stores=3659&stores=11&stores=278&stores=34&stores=12&stores=198&stores=3098&stores=1547&stores=4946&stores=1118&stores=28&stores=3824&stores=5177&stores=186&stores=2471&stores=18&stores=2009&stores=223&stores=2306&stores=2768&stores=194&stores=956&stores=2042&stores=293&stores=1877&stores=623&stores=67&stores=47&stores=86&stores=183&stores=22&stores=5672&stores=4550&stores=4352&stores=1514&stores=3165&stores=955&stores=2999&stores=1086&stores=2670&stores=2438&stores=4121&stores=2669&stores=176&stores=181&stores=4616&stores=167&stores=3032&stores=4715&stores=173&stores=264&stores=4220&stores=35&stores=170&stores=231&stores=2636&stores=6&stores=280&stores=2174&stores=2141&stores=789&stores=359&stores=2835&stores=44&stores=821&stores=63&stores=14&stores=239&stores=45&stores=1613&stores=85&stores=4386&stores=1151&stores=3230&stores=91&stores=3099"

  # Fetch the first page and return it
  response = session.get(url).json()
  yield response

  for page in range(2, 40): #Este valor puede ir cambiando
    response = session.get(url, params={'page': page}).json()
    yield response


df = pd.DataFrame()
for i in get_items_pages():    
    for j in range(len(i['results'])):
        try:
            df = pd.concat([df, pd.json_normalize(i['results'][j]['product_entries'][0])], axis='rows')
        except:
            print('Error al unir los datos')

    
df.shape
# Out:
# (337, 129)

# %%
df.head()
# Out:
#                                         product.name  \
# 0  ASRock Radeon RX 7900 XTX Phantom Gaming 24GB ...
# 0  Gigabyte AORUS RTX 3080 GAMING BOX [GV-N3080IX...
# 0  PNY GeForce RTX 3060 Ti 8GB UPRISING Dual Fan ...
# 0                        ASUS DUAL-RTX3060-O8G-WHITE
# 0                AMD Radeon Pro WX 3200 [100-506115]
#
#                                product.name_analyzed  product.brand_id  \
# 0  ASRock Radeon RX 7900 XTX Phantom Gaming 24GB ...               951
# 0  Gigabyte AORUS RTX 3080 GAMING BOX [GV-N3080IX...               140
# 0  PNY GeForce RTX 3060 Ti 8GB UPRISING Dual Fan ...               613
# 0                        ASUS DUAL-RTX3060-O8G-WHITE                74
# 0                AMD Radeon Pro WX 3200 [100-506115]               317
#
#   product.brand_name product.part_number  product.instance_model_id  \
# 0             ASRock   RX7900XTX PG 24GO                    1737593
# 0           Gigabyte                 NaN                    1411558
# 0                PNY                 NaN                    1614830
# 0               ASUS                 NaN                    1720028
# 0                AMD                 NaN                    1057214
#
#               product.creation_date              product.last_updated  \
# 0  2023-03-17T04:36:12.026791+00:00  2023-03-17T04:37:05.363349+00:00
# 0  2021-06-23T16:50:53.002245+00:00  2022-12-27T00:36:46.758655+00:00
# 0  2022-06-19T10:11:59.648175+00:00  2023-02-13T18:13:10.354449+00:00
# 0  2023-02-09T09:59:26.922852+00:00  2023-02-09T10:00:41.087674+00:00
# 0  2020-01-24T01:03:39.142363+00:00  2022-12-26T23:38:37.087619+00:00
#
#                                     product.keywords  product.specs.id  \
# 0  ASRock Radeon RX 7900 XTX Phantom Gaming 24GB ...           1737593
# 0  Gigabyte AORUS RTX 3080 GAMING BOX [GV-N3080IX...           1411558
# 0  PNY GeForce RTX 3060 Ti 8GB UPRISING Dual Fan ...           1614830
# 0  ASUS DUAL-RTX3060-O8G-WHITE 128 bit 128 NVIDIA...           1720028
# 0  AMD Radeon Pro WX 3200 [100-506115] 128 bit 12...           1057214
#
#                                product.specs.unicode  \
# 0  ASRock Radeon RX 7900 XTX Phantom Gaming 24GB ...
# 0  Gigabyte AORUS RTX 3080 GAMING BOX [GV-N3080IX...
# 0  PNY GeForce RTX 3060 Ti 8GB UPRISING Dual Fan ...
# 0                        ASUS DUAL-RTX3060-O8G-WHITE
# 0                AMD Radeon Pro WX 3200 [100-506115]
#
#    product.specs.memory_bus_width_id product.specs.memory_bus_width_unicode  \
# 0                             105362                                320 bit
# 0                             105362                                320 bit
# 0                             105355                                256 bit
# 0                             105338                                128 bit
# 0                             105338                                128 bit
#
#    product.specs.memory_bus_width_value  \
# 0                                   320
# 0                                   320
# 0                                   256
# 0                                   128
# 0                                   128
#
#                            product.specs.video_ports  \
# 0  [{'id': 106724, 'unicode': '3x DisplayPort', '...
# 0  [{'id': 106724, 'unicode': '3x DisplayPort', '...
# 0  [{'id': 106724, 'unicode': '3x DisplayPort', '...
# 0  [{'id': 106724, 'unicode': '3x DisplayPort', '...
# 0  [{'id': 106837, 'unicode': '4x Mini DisplayPor...
#
#                       product.specs.picture  product.specs.core_clock  \
# 0   products/1737593_picture_1679027814.jpg                      2615
# 0   products/1411558_picture_1624467172.png                      1710
# 0   products/1614830_picture_1655633574.jpg                      1665
# 0  products/1720028_picture_1675936802.webp                      1867
# 0   products/1057214_picture_1579827960.png                      1295
#
#    product.specs.length  product.specs.memory_clock  product.specs.profile_id  \
# 0                   330                        2500                    105817
# 0                   300                        1188                    105817
# 0                   251                        1750                    105817
# 0                   200                        1875                    105817
# 0                   168                        1000                    105817
#
#   product.specs.profile_unicode  product.specs.profile_size_value  \
# 0                        Normal                                 2
# 0                        Normal                                 2
# 0                        Normal                                 2
# 0                        Normal                                 2
# 0                        Normal                                 2
#
#   product.specs.profile_name  product.specs.bus_id product.specs.bus_unicode  \
# 0                     Normal                959749       PCI Express 4.0 x16
# 0                     Normal               1411517             Thunderbolt 3
# 0                     Normal                959749       PCI Express 4.0 x16
# 0                     Normal                959749       PCI Express 4.0 x16
# 0                     Normal                106697       PCI Express 3.0 x16
#
#    product.specs.bus_bus_id product.specs.bus_bus_unicode  \
# 0                    956619           PCI Express 4.0 x16
# 0                   1411515                 Thunderbolt 3
# 0                    956619           PCI Express 4.0 x16
# 0                    956619           PCI Express 4.0 x16
# 0                    106205           PCI Express 3.0 x16
#
#    product.specs.bus_bus_name_id product.specs.bus_bus_name_unicode  \
# 0                         105772                        PCI Express
# 0                        1411512                      Thunderbolt 3
# 0                         105772                        PCI Express
# 0                         105772                        PCI Express
# 0                         105772                        PCI Express
#
#   product.specs.bus_bus_name_name  \
# 0                     PCI Express
# 0                   Thunderbolt 3
# 0                     PCI Express
# 0                     PCI Express
# 0                     PCI Express
#
#    product.specs.bus_bus_name_show_version_and_lanes  \
# 0                                               True
# 0                                              False
# 0                                               True
# 0                                               True
# 0                                               True
#
#    product.specs.bus_bus_lane_id product.specs.bus_bus_lane_unicode  \
# 0                         105802                                x16
# 0                         105784                                 x1
# 0                         105802                                x16
# 0                         105802                                x16
# 0                         105802                                x16
#
#    product.specs.bus_bus_lane_value  product.specs.bus_bus_version  \
# 0                                16                            4.0
# 0                                 1                            3.0
# 0                                16                            4.0
# 0                                16                            4.0
# 0                                16                            3.0
#
#                            product.specs.power_conns  \
# 0  [{'id': 1292573, 'unicode': '3x 8 pines', 'qua...
# 0  [{'id': 1411535, 'unicode': '1x Conector PC', ...
# 0  [{'id': 106634, 'unicode': '1x 8 pines', 'conn...
# 0  [{'id': 106634, 'unicode': '1x 8 pines', 'conn...
# 0                                                NaN
#
#   product.specs.part_number  product.specs.memory_type_id  \
# 0         RX7900XTX PG 24GO                        819948
# 0         GV-N3080IXEB-10GD                       1240948
# 0           VCG3060T8LDFMPB                        819948
# 0                       NaN                        819948
# 0                100-506115                        105588
#
#   product.specs.memory_type_unicode product.specs.memory_type_name  \
# 0                             GDDR6                          GDDR6
# 0                            GDDR6X                         GDDR6X
# 0                             GDDR6                          GDDR6
# 0                             GDDR6                          GDDR6
# 0                             GDDR5                          GDDR5
#
#    product.specs.memory_quantity_id product.specs.memory_quantity_unicode  \
# 0                           1210948                                 24 GB
# 0                           1244421                                 10 GB
# 0                            105536                                  8 GB
# 0                            105536                                  8 GB
# 0                            105521                                  4 GB
#
#    product.specs.memory_quantity_value  \
# 0                                24576
# 0                                10240
# 0                                 8192
# 0                                 8192
# 0                                 4096
#
#                    product.specs.commercial_name  product.specs.has_backplate  \
# 0      Radeon RX 7900 XTX Phantom Gaming 24GB OC                         True
# 0                      AORUS RTX 3080 GAMING BOX                        False
# 0  GeForce RTX 3060 Ti 8GB UPRISING Dual Fan LHR                         True
# 0                         DUAL-RTX3060-O8G-WHITE                         True
# 0                             Radeon Pro WX 3200                        False
#
#    product.specs.illumination_id product.specs.illumination_unicode  \
# 0                        1179625                    RGB Programable
# 0                        1179625                    RGB Programable
# 0                        1179621                           No posee
# 0                        1179625                    RGB Programable
# 0                        1179627                        Desconocido
#
#   product.specs.illumination_name  product.specs.gpu_id  \
# 0                 RGB Programable               1705597
# 0                 RGB Programable               1244405
# 0                        No posee               1280689
# 0                 RGB Programable               1339546
# 0                     Desconocido               1057221
#
#     product.specs.gpu_unicode  product.specs.gpu_tdp  \
# 0      AMD Radeon RX 7900 XTX                    355
# 0     NVIDIA GeForce RTX 3080                    320
# 0  NVIDIA GeForce RTX 3060 Ti                    200
# 0     NVIDIA GeForce RTX 3060                    170
# 0      AMD Radeon Pro WX 3200                     65
#
#    product.specs.gpu_ray_tracing_cores  product.specs.gpu_boost_core_clock  \
# 0                                   96                                2499
# 0                                    0                                1710
# 0                                   38                                1665
# 0                                   28                                1777
# 0                                    0                                1295
#
#    product.specs.gpu_tdmark_fire_strike_score  \
# 0                                       47330
# 0                                       29694
# 0                                       23714
# 0                                       19592
# 0                                           0
#
#    product.specs.gpu_tdmark_time_spy_score  \
# 0                                    24486
# 0                                    15599
# 0                                    11078
# 0                                     8764
# 0                                        0
#
#    product.specs.gpu_tdmark_port_royal_score  \
# 0                                      15510
# 0                                      11440
# 0                                       6910
# 0                                       5152
# 0                                          0
#
#    product.specs.gpu_tdmark_vr_room_orange_score  \
# 0                                          14982
# 0                                          11656
# 0                                           9254
# 0                                          10916
# 0                                              0
#
#    product.specs.gpu_has_multi_gpu_support  \
# 0                                    False
# 0                                    False
# 0                                    False
# 0                                    False
# 0                                    False
#
#    product.specs.gpu_manufacturing_process_id  \
# 0                                     1686463
# 0                                     1240905
# 0                                     1240905
# 0                                     1240905
# 0                                      506813
#
#   product.specs.gpu_manufacturing_process_unicode  \
# 0                                            5 nm
# 0                                            8 nm
# 0                                            8 nm
# 0                                            8 nm
# 0                                           14 nm
#
#    product.specs.gpu_manufacturing_process_value  product.specs.gpu_core_id  \
# 0                                              5                    1705595
# 0                                              8                    1240911
# 0                                              8                    1265952
# 0                                              8                    1339544
# 0                                             14                     619984
#
#   product.specs.gpu_core_unicode product.specs.gpu_core_name  \
# 0         AMD RDNA 3 Navi 31 XTX                 Navi 31 XTX
# 0            NVIDIA Ampere GA102                       GA102
# 0            NVIDIA Ampere GA104                       GA104
# 0            NVIDIA Ampere GA106                       GA106
# 0   AMD Artic Islands Polaris 12                  Polaris 12
#
#    product.specs.gpu_core_family_id product.specs.gpu_core_family_unicode  \
# 0                           1686467                            AMD RDNA 3
# 0                           1339543                         NVIDIA Ampere
# 0                           1339543                         NVIDIA Ampere
# 0                           1339543                         NVIDIA Ampere
# 0                            506817             AMD Artic Islands Polaris
#
#    product.specs.gpu_core_family_architecture_id  \
# 0                                        1686465
# 0                                        1240907
# 0                                        1240907
# 0                                        1240907
# 0                                         506815
#
#   product.specs.gpu_core_family_architecture_unicode  \
# 0                                         AMD RDNA 3
# 0                                      NVIDIA Ampere
# 0                                      NVIDIA Ampere
# 0                                      NVIDIA Ampere
# 0                                  AMD Artic Islands
#
#    product.specs.gpu_core_family_architecture_brand_id  \
# 0                                             106027
# 0                                             106034
# 0                                             106034
# 0                                             106034
# 0                                             106027
#
#   product.specs.gpu_core_family_architecture_brand_unicode  \
# 0                                                AMD
# 0                                             NVIDIA
# 0                                             NVIDIA
# 0                                             NVIDIA
# 0                                                AMD
#
#    product.specs.gpu_core_family_architecture_brand_brand_id  \
# 0                                             104107
# 0                                             104691
# 0                                             104691
# 0                                             104691
# 0                                             104107
#
#   product.specs.gpu_core_family_architecture_brand_brand_unicode  \
# 0                                                AMD
# 0                                             NVIDIA
# 0                                             NVIDIA
# 0                                             NVIDIA
# 0                                                AMD
#
#   product.specs.gpu_core_family_architecture_brand_brand_name  \
# 0                                                AMD
# 0                                             NVIDIA
# 0                                             NVIDIA
# 0                                             NVIDIA
# 0                                                AMD
#
#   product.specs.gpu_core_family_architecture_name  product.specs.gpu_line_id  \
# 0                                          RDNA 3                    1686470
# 0                                          Ampere                    1240913
# 0                                          Ampere                    1240913
# 0                                          Ampere                    1240913
# 0                                   Artic Islands                    1019090
#
#   product.specs.gpu_line_unicode product.specs.gpu_line_name  \
# 0      AMD Radeon RX 7000 Series              RX 7000 Series
# 0   NVIDIA GeForce RTX 30 Series               RTX 30 Series
# 0   NVIDIA GeForce RTX 30 Series               RTX 30 Series
# 0   NVIDIA GeForce RTX 30 Series               RTX 30 Series
# 0          AMD Radeon Pro Series                      Series
#
#    product.specs.gpu_line_family_id product.specs.gpu_line_family_unicode  \
# 0                            106049                            AMD Radeon
# 0                            106058                        NVIDIA GeForce
# 0                            106058                        NVIDIA GeForce
# 0                            106058                        NVIDIA GeForce
# 0                           1669329                        AMD Radeon Pro
#
#    product.specs.gpu_line_family_brand_id  \
# 0                                  106027
# 0                                  106034
# 0                                  106034
# 0                                  106034
# 0                                  106027
#
#   product.specs.gpu_line_family_brand_unicode  \
# 0                                         AMD
# 0                                      NVIDIA
# 0                                      NVIDIA
# 0                                      NVIDIA
# 0                                         AMD
#
#    product.specs.gpu_line_family_brand_brand_id  \
# 0                                        104107
# 0                                        104691
# 0                                        104691
# 0                                        104691
# 0                                        104107
#
#   product.specs.gpu_line_family_brand_brand_unicode  \
# 0                                               AMD
# 0                                            NVIDIA
# 0                                            NVIDIA
# 0                                            NVIDIA
# 0                                               AMD
#
#   product.specs.gpu_line_family_brand_brand_name  \
# 0                                            AMD
# 0                                         NVIDIA
# 0                                         NVIDIA
# 0                                         NVIDIA
# 0                                            AMD
#
#   product.specs.gpu_line_family_name  product.specs.gpu_dx_version_id  \
# 0                             Radeon                          1280687
# 0                            GeForce                          1280687
# 0                            GeForce                          1280687
# 0                            GeForce                          1280687
# 0                         Radeon Pro                           105115
#
#   product.specs.gpu_dx_version_unicode  product.specs.gpu_dx_version_value  \
# 0                                 12.2                                12.2
# 0                                 12.2                                12.2
# 0                                 12.2                                12.2
# 0                                 12.2                                12.2
# 0                                 12.0                                12.0
#
#    product.specs.gpu_ogl_version_id product.specs.gpu_ogl_version_unicode  \
# 0                            671636                                   4.6
# 0                            671636                                   4.6
# 0                            671636                                   4.6
# 0                            671636                                   4.6
# 0                            671636                                   4.6
#
#    product.specs.gpu_ogl_version_value  product.specs.gpu_core_count_id  \
# 0                                  4.6                           105198
# 0                                  4.6                           105198
# 0                                  4.6                           105198
# 0                                  4.6                           105198
# 0                                  4.6                           105198
#
#   product.specs.gpu_core_count_unicode  product.specs.gpu_core_count_value  \
# 0                          Single-core                                   1
# 0                          Single-core                                   1
# 0                          Single-core                                   1
# 0                          Single-core                                   1
# 0                          Single-core                                   1
#
#   product.specs.gpu_core_count_name product.specs.gpu_name  \
# 0                       Single-core            RX 7900 XTX
# 0                       Single-core               RTX 3080
# 0                       Single-core            RTX 3060 Ti
# 0                       Single-core               RTX 3060
# 0                       Single-core                WX 3200
#
#    product.specs.gpu_transistor_count  product.specs.gpu_stream_processors  \
# 0                               57700                                 6144
# 0                               28300                                 8704
# 0                               17400                                 4664
# 0                               13250                                 3584
# 0                                2200                                  640
#
#    product.specs.gpu_texture_units  product.specs.gpu_rops  \
# 0                              384                     192
# 0                              272                      96
# 0                              152                      80
# 0                              112                      48
# 0                               32                      16
#
#    product.specs.gpu_default_core_clock  \
# 0                                  1855
# 0                                  1440
# 0                                  1410
# 0                                  1320
# 0                                  1295
#
#    product.specs.gpu_default_memory_clock product.specs.gpu_brand_unicode  \
# 0                                    2500                             AMD
# 0                                    1188                          NVIDIA
# 0                                    1750                          NVIDIA
# 0                                    1875                          NVIDIA
# 0                                    1000                             AMD
#
#    product.specs.brand_id product.specs.brand_unicode  \
# 0                  765020                      ASRock
# 0                  105646                    Gigabyte
# 0                  105684                         PNY
# 0                  105611                        ASUS
# 0                  105605                         AMD
#
#    product.specs.brand_brand_id product.specs.brand_brand_unicode  \
# 0                        104144                            ASRock
# 0                        104413                          Gigabyte
# 0                        104770                               PNY
# 0                        104149                              ASUS
# 0                        104107                               AMD
#
#   product.specs.brand_brand_name  product.specs.brand_display_part_number  \
# 0                         ASRock                                     True
# 0                       Gigabyte                                     True
# 0                            PNY                                     True
# 0                           ASUS                                     True
# 0                            AMD                                     True
#
#    product.specs.refrigeration_id product.specs.refrigeration_unicode  \
# 0                          105868                          Ventilador
# 0                          105854                             Líquida
# 0                          105868                          Ventilador
# 0                          105868                          Ventilador
# 0                          105868                          Ventilador
#
#   product.specs.refrigeration_name  product.specs.slot_type_id  \
# 0                       Ventilador                      105834
# 0                          Líquida                      105834
# 0                       Ventilador                      105834
# 0                       Ventilador                      105834
# 0                       Ventilador                      105825
#
#   product.specs.slot_type_unicode product.specs.slot_type_name  \
# 0                       Dual slot                    Dual slot
# 0                       Dual slot                    Dual slot
# 0                       Dual slot                    Dual slot
# 0                       Dual slot                    Dual slot
# 0                     Single slot                  Single slot
#
#    product.specs.slot_type_value  product.specs.display_core_clock  \
# 0                              2                              True
# 0                              2                             False
# 0                              2                             False
# 0                              2                              True
# 0                              1                             False
#
#    product.specs.display_memory_clock  product.specs.default_bucket  \
# 0                               False                       1737593
# 0                               False                       1411558
# 0                               False                       1614830
# 0                               False                       1720028
# 0                               False                       1057214
#
#    product.id                                      product.url  \
# 0      190276  https://publicapi.solotodo.com/products/190276/
# 0      114051  https://publicapi.solotodo.com/products/114051/
# 0      144243  https://publicapi.solotodo.com/products/144243/
# 0      179024  https://publicapi.solotodo.com/products/179024/
# 0       72746   https://publicapi.solotodo.com/products/72746/
#
#                                product.category  \
# 0  https://publicapi.solotodo.com/categories/2/
# 0  https://publicapi.solotodo.com/categories/2/
# 0  https://publicapi.solotodo.com/categories/2/
# 0  https://publicapi.solotodo.com/categories/2/
# 0  https://publicapi.solotodo.com/categories/2/
#
#                                         product.slug  \
# 0  asrock-radeon-rx-7900-xtx-phantom-gaming-24gb-...
# 0  gigabyte-aorus-rtx-3080-gaming-box-gv-n3080ixe...
# 0  pny-geforce-rtx-3060-ti-8gb-uprising-dual-fan-...
# 0                        asus-dual-rtx3060-o8g-white
# 0                  amd-radeon-pro-wx-3200-100-506115
#
#                                  product.picture_url  metadata.score  \
# 0  https://media.solotodo.com/media/products/1737...           38.09
# 0  https://media.solotodo.com/media/products/1411...           12.29
# 0  https://media.solotodo.com/media/products/1614...            6.25
# 0  https://media.solotodo.com/media/products/1720...            2.46
# 0  https://media.solotodo.com/media/products/1057...            0.00
#
#                         metadata.prices_per_currency  \
# 0  [{'currency': 'https://publicapi.solotodo.com/...
# 0  [{'currency': 'https://publicapi.solotodo.com/...
# 0  [{'currency': 'https://publicapi.solotodo.com/...
# 0  [{'currency': 'https://publicapi.solotodo.com/...
# 0  [{'currency': 'https://publicapi.solotodo.com/...
#
#   metadata.normal_price_usd metadata.offer_price_usd  \
# 0                   1411.99                  1411.99
# 0                   1032.15                  1032.15
# 0                    583.71                   577.46
# 0                    446.07                   446.07
# 0                    296.35                   286.33
#
#   product.specs.gpu_core_family_name
# 0                                NaN
# 0                                NaN
# 0                                NaN
# 0                                NaN
# 0                            Polaris

# %% [markdown]
# ### Diccionario para mapear la info que necesitamos con la data de la API
#
# 1. ID: Debe ser un número, puede ser secuencial del 1 al X -> Podemos setear un index después
# 2. Marca: La marca de la tarjeta deber ser “Nvidia” o “AMD” -> Columna `product.specs.gpu_line_family_brand_brand_name`
# 3. Modelo: El modelo deber ser “”RTX 3070”, “RX 6700 XT”, etc -> Columna `product.specs.gpu_name`
# 4. Fabricante: El fabricante debe ser “Gigabyte”, “Powercolor”, “XFX”, etc -> Columna `product.brand_name`
# 5. Núcleos de procesamiento: Debe ser un número indicando cantidad -> Columna `product.specs.gpu_stream_processors`
# 6. Chip de la tarjeta: Debe ser “AMD Radeon RX 6700 XT”, “Nvidia Geforce RTX 3070 Ti”, etc -> Columna `product.specs.gpu_unicode`
# 7. Velocidad de reloj: Debe ser “2357”. Se mide en MHz. -> Columna `product.specs.core_clock`
# 8. Memoria de video(VRAM): Debe ser “16”, “8”. Se mide en GB. -> Columna `product.specs.memory_quantity_value` o sino `product.specs.memory_quantity_unicode`
# 9. Ancho de banda del bus de memoria: Debe ser “256”. Se mide en bits -> Columna `product.specs.memory_bus_width_value`
# 10. Interfaz de memoria: Debe ser “GDDR6”, “GDDR5”, etc. -> Columna `product.specs.memory_type_name` o `product.specs.memory_type_unicode`
# 11. Resolución máxima soportada: Debe ser “1440p”, “4k”, “1080p”, etc. -> No está ese dato **Ver como crearlo**
# 12. Consumo de energía o TDP: Debe ser “”250”, “300”, etc. Se mide en Watts -> Columna `product.specs.gpu_tdp`
# 13. Conectores de video: Debe ser “2xHDMI 2.1 1xDisplayPort 1.4”, etc. -> Columna `product.specs.video_ports` pero falta arreglarlo. **Hacer una función para extraer esos datos**
# 14. Fecha de recopilación de la información: Debe ser “14/03/2023”. Formato date -> Hacer una columna datetime
# 15. Link de la página web: Debe ser “https://www.solotodo.cl/{id}”, etc. -> Ver como creo el link en base a la info.
# 16. Largo de la tarjeta: Debe ser “30”. Se mide en cm -> Columna `product.specs.length`
# 17. Precio normal en dolares: Debe ser “1250”. Se mide en dólares. -> Columna `metadata.normal_price_usd` o `metadata.offer_price_usd` pero hay que arreglarlo bien. **Crear una función para extraer el precio o los precios de la API.**
# 18. Precio oferta de la tarjeta pesos chilenos
# 19. Precio normal de la tarjeta pesos chilenos
# 20. Precio oferta de la tarjeta en dólares
# 21. Tipo de bus de la tarjeta: Debe ser "PCI Express 3.0 x8" -> Columna `product.specs.bus_unicode`

# %% [markdown]
# ## Creación del dataframe base

# %%
columnas = ['product.specs.gpu_line_family_brand_brand_name', 'product.specs.gpu_name',
            'product.brand_name', 'product.specs.gpu_stream_processors',
            'product.specs.gpu_unicode', 'product.specs.core_clock',
            'product.specs.memory_quantity_value', 'product.specs.memory_bus_width_value',
            'product.specs.memory_type_name', 'product.specs.gpu_tdp',
            'product.specs.length', 'product.specs.bus_unicode',
            'metadata.normal_price_usd', 'metadata.offer_price_usd']
            
#Estas dos columnas son en pesos chilenos 'metadata.prices_per_currency.normal_price', 'metadata.prices_per_currency.offer_price'
# Hacer función para extraer esa data.

df_base = df[columnas]

# %%
df_base.shape
# Out:
# (337, 14)

# %%
df.columns
# Out:
# Index(['product.name', 'product.name_analyzed', 'product.brand_id',
#        'product.brand_name', 'product.part_number',
#        'product.instance_model_id', 'product.creation_date',
#        'product.last_updated', 'product.keywords', 'product.specs.id',
#        ...
#        'product.id', 'product.url', 'product.category', 'product.slug',
#        'product.picture_url', 'metadata.score', 'metadata.prices_per_currency',
#        'metadata.normal_price_usd', 'metadata.offer_price_usd',
#        'product.specs.gpu_core_family_name'],
#       dtype='object', length=129)

# %% [markdown]
# ## Columnas que nos falta agregar bien
#
# <ol>
#     <li><del>Precio normal de la tarjeta en pesos chilenos</del></li>
#     <li><del>Precio oferta de la tarjeta en pesos chilenos</del></li>
#     <li><del>Conectores de video disponibles en la tarjeta</del></li>
#     <li><del>Link URL de la tarjeta</del></li>
#     <li><del>Fecha de obtención de la información</del></li>
#     <li><del>Resolución máxima soportada por la tarjeta</del></li>
# </ol>

# %% [markdown]
# ### Creacion de la columna `precio_normal_pesos_chilenos`

# %%
precio_normal_chileno = []
for i in df['metadata.prices_per_currency']:
    precio_normal_chileno.append(i[0]['normal_price'])

precio_normal_chileno[:5]
# Out:
# ['1148990.0', '839900.0', '474990.0', '362989.0', '241155.0']

# %%
df1 = df_base.copy()
df1['precio_normal_pesos_chilenos'] = precio_normal_chileno

# %%
df1.head()
# Out:
#   product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                            AMD            RX 7900 XTX
# 0                                         NVIDIA               RTX 3080
# 0                                         NVIDIA            RTX 3060 Ti
# 0                                         NVIDIA               RTX 3060
# 0                                            AMD                WX 3200
#
#   product.brand_name  product.specs.gpu_stream_processors  \
# 0             ASRock                                 6144
# 0           Gigabyte                                 8704
# 0                PNY                                 4664
# 0               ASUS                                 3584
# 0                AMD                                  640
#
#     product.specs.gpu_unicode  product.specs.core_clock  \
# 0      AMD Radeon RX 7900 XTX                      2615
# 0     NVIDIA GeForce RTX 3080                      1710
# 0  NVIDIA GeForce RTX 3060 Ti                      1665
# 0     NVIDIA GeForce RTX 3060                      1867
# 0      AMD Radeon Pro WX 3200                      1295
#
#    product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                24576                                   320
# 0                                10240                                   320
# 0                                 8192                                   256
# 0                                 8192                                   128
# 0                                 4096                                   128
#
#   product.specs.memory_type_name  product.specs.gpu_tdp  product.specs.length  \
# 0                          GDDR6                    355                   330
# 0                         GDDR6X                    320                   300
# 0                          GDDR6                    200                   251
# 0                          GDDR6                    170                   200
# 0                          GDDR5                     65                   168
#
#   product.specs.bus_unicode metadata.normal_price_usd  \
# 0       PCI Express 4.0 x16                   1411.99
# 0             Thunderbolt 3                   1032.15
# 0       PCI Express 4.0 x16                    583.71
# 0       PCI Express 4.0 x16                    446.07
# 0       PCI Express 3.0 x16                    296.35
#
#   metadata.offer_price_usd precio_normal_pesos_chilenos
# 0                  1411.99                    1148990.0
# 0                  1032.15                     839900.0
# 0                   577.46                     474990.0
# 0                   446.07                     362989.0
# 0                   286.33                     241155.0

# %% [markdown]
# ### Creacion de la columna `precio_oferta_pesos_chilenos`

# %%
precio_oferta_chileno = []
for i in df['metadata.prices_per_currency']:
    precio_oferta_chileno.append(i[0]['offer_price'])

precio_oferta_chileno[:5]
# Out:
# ['1148990.0', '839900.0', '469900.0', '362989.0', '233000.0']

# %%
df2 = df1.copy()
df2['precio_oferta_pesos_chilenos'] = precio_oferta_chileno

# %%
df2.head()
# Out:
#   product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                            AMD            RX 7900 XTX
# 0                                         NVIDIA               RTX 3080
# 0                                         NVIDIA            RTX 3060 Ti
# 0                                         NVIDIA               RTX 3060
# 0                                            AMD                WX 3200
#
#   product.brand_name  product.specs.gpu_stream_processors  \
# 0             ASRock                                 6144
# 0           Gigabyte                                 8704
# 0                PNY                                 4664
# 0               ASUS                                 3584
# 0                AMD                                  640
#
#     product.specs.gpu_unicode  product.specs.core_clock  \
# 0      AMD Radeon RX 7900 XTX                      2615
# 0     NVIDIA GeForce RTX 3080                      1710
# 0  NVIDIA GeForce RTX 3060 Ti                      1665
# 0     NVIDIA GeForce RTX 3060                      1867
# 0      AMD Radeon Pro WX 3200                      1295
#
#    product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                24576                                   320
# 0                                10240                                   320
# 0                                 8192                                   256
# 0                                 8192                                   128
# 0                                 4096                                   128
#
#   product.specs.memory_type_name  product.specs.gpu_tdp  product.specs.length  \
# 0                          GDDR6                    355                   330
# 0                         GDDR6X                    320                   300
# 0                          GDDR6                    200                   251
# 0                          GDDR6                    170                   200
# 0                          GDDR5                     65                   168
#
#   product.specs.bus_unicode metadata.normal_price_usd  \
# 0       PCI Express 4.0 x16                   1411.99
# 0             Thunderbolt 3                   1032.15
# 0       PCI Express 4.0 x16                    583.71
# 0       PCI Express 4.0 x16                    446.07
# 0       PCI Express 3.0 x16                    296.35
#
#   metadata.offer_price_usd precio_normal_pesos_chilenos  \
# 0                  1411.99                    1148990.0
# 0                  1032.15                     839900.0
# 0                   577.46                     474990.0
# 0                   446.07                     362989.0
# 0                   286.33                     241155.0
#
#   precio_oferta_pesos_chilenos
# 0                    1148990.0
# 0                     839900.0
# 0                     469900.0
# 0                     362989.0
# 0                     233000.0

# %% [markdown]
# ### Creacion de la columna `conectores_de_video`

# %%
import numpy as np
lista_conectores_video = []
for i in df['product.specs.video_ports']:
    try:
        #DisplayPort            #HDMI
        lista_conectores_video.append(i[0]['unicode'] + '; ' + i[1]['unicode'])
    except:
        lista_conectores_video.append(np.nan)

lista_conectores_video[:5]
# Out:
# ['3x DisplayPort; 1x HDMI',
#  '3x DisplayPort; 2x HDMI',
#  '3x DisplayPort; 1x HDMI',
#  '3x DisplayPort; 1x HDMI',
#  nan]

# %%
df3 = df2.copy()
df3['conectores_de_video'] = lista_conectores_video

# %%
df3.head()
# Out:
#   product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                            AMD            RX 7900 XTX
# 0                                         NVIDIA               RTX 3080
# 0                                         NVIDIA            RTX 3060 Ti
# 0                                         NVIDIA               RTX 3060
# 0                                            AMD                WX 3200
#
#   product.brand_name  product.specs.gpu_stream_processors  \
# 0             ASRock                                 6144
# 0           Gigabyte                                 8704
# 0                PNY                                 4664
# 0               ASUS                                 3584
# 0                AMD                                  640
#
#     product.specs.gpu_unicode  product.specs.core_clock  \
# 0      AMD Radeon RX 7900 XTX                      2615
# 0     NVIDIA GeForce RTX 3080                      1710
# 0  NVIDIA GeForce RTX 3060 Ti                      1665
# 0     NVIDIA GeForce RTX 3060                      1867
# 0      AMD Radeon Pro WX 3200                      1295
#
#    product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                24576                                   320
# 0                                10240                                   320
# 0                                 8192                                   256
# 0                                 8192                                   128
# 0                                 4096                                   128
#
#   product.specs.memory_type_name  product.specs.gpu_tdp  product.specs.length  \
# 0                          GDDR6                    355                   330
# 0                         GDDR6X                    320                   300
# 0                          GDDR6                    200                   251
# 0                          GDDR6                    170                   200
# 0                          GDDR5                     65                   168
#
#   product.specs.bus_unicode metadata.normal_price_usd  \
# 0       PCI Express 4.0 x16                   1411.99
# 0             Thunderbolt 3                   1032.15
# 0       PCI Express 4.0 x16                    583.71
# 0       PCI Express 4.0 x16                    446.07
# 0       PCI Express 3.0 x16                    296.35
#
#   metadata.offer_price_usd precio_normal_pesos_chilenos  \
# 0                  1411.99                    1148990.0
# 0                  1032.15                     839900.0
# 0                   577.46                     474990.0
# 0                   446.07                     362989.0
# 0                   286.33                     241155.0
#
#   precio_oferta_pesos_chilenos      conectores_de_video
# 0                    1148990.0  3x DisplayPort; 1x HDMI
# 0                     839900.0  3x DisplayPort; 2x HDMI
# 0                     469900.0  3x DisplayPort; 1x HDMI
# 0                     362989.0  3x DisplayPort; 1x HDMI
# 0                     233000.0                      NaN

# %% [markdown]
# ### Creacion del link de búsqueda de la tarjeta

# %% [markdown]
# Para el link podemos buscar el producto de la siguiente manera: "https://www.solotodo.cl/products/{id}" siendo el id el identificador de la tarjeta que podemos obtener de los datos obtenidos por la api

# %%
lista_urls = []
for i in df['product.id']:
    lista_urls.append(f'https://www.solotodo.cl/products/{i}')
lista_urls[:5]
# Out:
# ['https://www.solotodo.cl/products/190276',
#  'https://www.solotodo.cl/products/114051',
#  'https://www.solotodo.cl/products/144243',
#  'https://www.solotodo.cl/products/179024',
#  'https://www.solotodo.cl/products/72746']

# %%
df4 = df3.copy()
df4['link_tarjeta'] = lista_urls

# %%
df4.head()
# Out:
#   product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                            AMD            RX 7900 XTX
# 0                                         NVIDIA               RTX 3080
# 0                                         NVIDIA            RTX 3060 Ti
# 0                                         NVIDIA               RTX 3060
# 0                                            AMD                WX 3200
#
#   product.brand_name  product.specs.gpu_stream_processors  \
# 0             ASRock                                 6144
# 0           Gigabyte                                 8704
# 0                PNY                                 4664
# 0               ASUS                                 3584
# 0                AMD                                  640
#
#     product.specs.gpu_unicode  product.specs.core_clock  \
# 0      AMD Radeon RX 7900 XTX                      2615
# 0     NVIDIA GeForce RTX 3080                      1710
# 0  NVIDIA GeForce RTX 3060 Ti                      1665
# 0     NVIDIA GeForce RTX 3060                      1867
# 0      AMD Radeon Pro WX 3200                      1295
#
#    product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                24576                                   320
# 0                                10240                                   320
# 0                                 8192                                   256
# 0                                 8192                                   128
# 0                                 4096                                   128
#
#   product.specs.memory_type_name  product.specs.gpu_tdp  product.specs.length  \
# 0                          GDDR6                    355                   330
# 0                         GDDR6X                    320                   300
# 0                          GDDR6                    200                   251
# 0                          GDDR6                    170                   200
# 0                          GDDR5                     65                   168
#
#   product.specs.bus_unicode metadata.normal_price_usd  \
# 0       PCI Express 4.0 x16                   1411.99
# 0             Thunderbolt 3                   1032.15
# 0       PCI Express 4.0 x16                    583.71
# 0       PCI Express 4.0 x16                    446.07
# 0       PCI Express 3.0 x16                    296.35
#
#   metadata.offer_price_usd precio_normal_pesos_chilenos  \
# 0                  1411.99                    1148990.0
# 0                  1032.15                     839900.0
# 0                   577.46                     474990.0
# 0                   446.07                     362989.0
# 0                   286.33                     241155.0
#
#   precio_oferta_pesos_chilenos      conectores_de_video  \
# 0                    1148990.0  3x DisplayPort; 1x HDMI
# 0                     839900.0  3x DisplayPort; 2x HDMI
# 0                     469900.0  3x DisplayPort; 1x HDMI
# 0                     362989.0  3x DisplayPort; 1x HDMI
# 0                     233000.0                      NaN
#
#                               link_tarjeta
# 0  https://www.solotodo.cl/products/190276
# 0  https://www.solotodo.cl/products/114051
# 0  https://www.solotodo.cl/products/144243
# 0  https://www.solotodo.cl/products/179024
# 0   https://www.solotodo.cl/products/72746

# %% [markdown]
# ### Creacion de la columna `fecha_obtencion_info`

# %%
import datetime
lista_fechas = [datetime.datetime.now().strftime("%d/%m/%Y") for i in range(len(df))]
lista_fechas[:5]
# Out:
# ['10/04/2023', '10/04/2023', '10/04/2023', '10/04/2023', '10/04/2023']

# %%
df5 = df4.copy()
df5['fecha_obtencion_info'] = lista_fechas

# %%
df5
# Out:
#    product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                             AMD            RX 7900 XTX
# 0                                          NVIDIA               RTX 3080
# 0                                          NVIDIA            RTX 3060 Ti
# 0                                          NVIDIA               RTX 3060
# 0                                             AMD                WX 3200
# ..                                            ...                    ...
# 0                                           Intel                   A380
# 0                                          NVIDIA               RTX 3050
# 0                                          NVIDIA            RTX 4070 Ti
# 0                                          NVIDIA                  A2000
# 0                                          NVIDIA               RTX 4080
#
#    product.brand_name  product.specs.gpu_stream_processors  \
# 0              ASRock                                 6144
# 0            Gigabyte                                 8704
# 0                 PNY                                 4664
# 0                ASUS                                 3584
# 0                 AMD                                  640
# ..                ...                                  ...
# 0              ASRock                                 1024
# 0               Palit                                 2560
# 0            Gigabyte                                 7680
# 0                 PNY                                 3328
# 0                 MSI                                 9728
#
#      product.specs.gpu_unicode  product.specs.core_clock  \
# 0       AMD Radeon RX 7900 XTX                      2615
# 0      NVIDIA GeForce RTX 3080                      1710
# 0   NVIDIA GeForce RTX 3060 Ti                      1665
# 0      NVIDIA GeForce RTX 3060                      1867
# 0       AMD Radeon Pro WX 3200                      1295
# ..                         ...                       ...
# 0               Intel Arc A380                      2250
# 0      NVIDIA GeForce RTX 3050                      1777
# 0   NVIDIA GeForce RTX 4070 Ti                      2625
# 0          NVIDIA Quadro A2000                      1200
# 0      NVIDIA GeForce RTX 4080                      2520
#
#     product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                 24576                                   320
# 0                                 10240                                   320
# 0                                  8192                                   256
# 0                                  8192                                   128
# 0                                  4096                                   128
# ..                                  ...                                   ...
# 0                                  6144                                    96
# 0                                  8192                                   128
# 0                                 12288                                   192
# 0                                 12288                                   192
# 0                                 16384                                   256
#
#    product.specs.memory_type_name  product.specs.gpu_tdp  \
# 0                           GDDR6                    355
# 0                          GDDR6X                    320
# 0                           GDDR6                    200
# 0                           GDDR6                    170
# 0                           GDDR5                     65
# ..                            ...                    ...
# 0                           GDDR6                     75
# 0                           GDDR6                    130
# 0                          GDDR6X                    285
# 0                           GDDR6                     70
# 0                          GDDR6X                    320
#
#     product.specs.length product.specs.bus_unicode metadata.normal_price_usd  \
# 0                    330       PCI Express 4.0 x16                   1411.99
# 0                    300             Thunderbolt 3                   1032.15
# 0                    251       PCI Express 4.0 x16                    583.71
# 0                    200       PCI Express 4.0 x16                    446.07
# 0                    168       PCI Express 3.0 x16                    296.35
# ..                   ...                       ...                       ...
# 0                    190        PCI Express 4.0 x8                    184.32
# 0                    172        PCI Express 4.0 x8                    413.88
# 0                    301       PCI Express 4.0 x16                    1335.8
# 0                    168       PCI Express 4.0 x16                   1280.64
# 0                    322       PCI Express 4.0 x16        1623.1100000000001
#
#    metadata.offer_price_usd precio_normal_pesos_chilenos  \
# 0                   1411.99                    1148990.0
# 0                   1032.15                     839900.0
# 0                    577.46                     474990.0
# 0                    446.07                     362989.0
# 0                    286.33                     241155.0
# ..                      ...                          ...
# 0                    184.32                     149990.0
# 0                    393.23                     336790.0
# 0                    1335.8                    1086990.0
# 0        1216.6000000000001                    1042105.0
# 0                   1560.68                    1320790.0
#
#    precio_oferta_pesos_chilenos                conectores_de_video  \
# 0                     1148990.0            3x DisplayPort; 1x HDMI
# 0                      839900.0            3x DisplayPort; 2x HDMI
# 0                      469900.0            3x DisplayPort; 1x HDMI
# 0                      362989.0            3x DisplayPort; 1x HDMI
# 0                      233000.0                                NaN
# ..                          ...                                ...
# 0                      149990.0            3x DisplayPort; 1x HDMI
# 0                      319990.0       1x Display Port 1.4a; 1x DVI
# 0                     1086990.0        3x DisplayPort; 1x HDMI 2.1
# 0                      990000.0                                NaN
# 0                     1269990.0  3x Display Port 1.4a; 1x HDMI 2.1
#
#                                link_tarjeta fecha_obtencion_info
# 0   https://www.solotodo.cl/products/190276           10/04/2023
# 0   https://www.solotodo.cl/products/114051           10/04/2023
# 0   https://www.solotodo.cl/products/144243           10/04/2023
# 0   https://www.solotodo.cl/products/179024           10/04/2023
# 0    https://www.solotodo.cl/products/72746           10/04/2023
# ..                                      ...                  ...
# 0   https://www.solotodo.cl/products/187383           10/04/2023
# 0   https://www.solotodo.cl/products/183117           10/04/2023
# 0   https://www.solotodo.cl/products/196249           10/04/2023
# 0   https://www.solotodo.cl/products/156590           10/04/2023
# 0   https://www.solotodo.cl/products/195228           10/04/2023
#
# [337 rows x 19 columns]

# %% [markdown]
# ### Creación de la columna `resolucion_maxima_soportada`

# %%
df_resolution = pd.read_csv('resoluciones_maximas_tarjetas.csv', sep=';')
df_resolution
# Out:
#    Tarjeta Gráfica Resolución máxima para jugar juegos
# 0         RTX 3050                               1080p
# 1         RTX 3060                               1440p
# 2      RTX 3060 Ti                               1440p
# 3         RTX 3070                                  4K
# 4      RTX 3070 Ti                                  4K
# 5         RTX 3080                                  4K
# 6      RTX 3080 Ti                                  4K
# 7         RTX 3090                                  4K
# 8      RTX 3090 Ti                                  4K
# 9         RTX 4090                                  8K
# 10        RTX 4080                                  8K
# 11     RTX 4070 Ti                                  8K
# 12      RX 6500 XT                               1080p
# 13         RX 6600                               1440p
# 14      RX 6600 XT                               1440p
# 15      RX 6650 XT                               1440p
# 16      RX 6700 XT                               1440p
# 17      RX 6750 XT                               1440p
# 18         RX 6800                                  4K
# 19      RX 6800 XT                                  4K
# 20      RX 6900 XT                                  4K
# 21     RX 7900 XTX                                  4K
# 22      RX 7900 XT                                  4K

# %%
df6 = df5.copy()
df6['resolucion_maxima_soportada'] = df6['product.specs.gpu_name'].map(df_resolution.set_index('Tarjeta Gráfica')['Resolución máxima para jugar juegos'])
df6.head()
# Out:
#   product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                            AMD            RX 7900 XTX
# 0                                         NVIDIA               RTX 3080
# 0                                         NVIDIA            RTX 3060 Ti
# 0                                         NVIDIA               RTX 3060
# 0                                            AMD                WX 3200
#
#   product.brand_name  product.specs.gpu_stream_processors  \
# 0             ASRock                                 6144
# 0           Gigabyte                                 8704
# 0                PNY                                 4664
# 0               ASUS                                 3584
# 0                AMD                                  640
#
#     product.specs.gpu_unicode  product.specs.core_clock  \
# 0      AMD Radeon RX 7900 XTX                      2615
# 0     NVIDIA GeForce RTX 3080                      1710
# 0  NVIDIA GeForce RTX 3060 Ti                      1665
# 0     NVIDIA GeForce RTX 3060                      1867
# 0      AMD Radeon Pro WX 3200                      1295
#
#    product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                24576                                   320
# 0                                10240                                   320
# 0                                 8192                                   256
# 0                                 8192                                   128
# 0                                 4096                                   128
#
#   product.specs.memory_type_name  product.specs.gpu_tdp  product.specs.length  \
# 0                          GDDR6                    355                   330
# 0                         GDDR6X                    320                   300
# 0                          GDDR6                    200                   251
# 0                          GDDR6                    170                   200
# 0                          GDDR5                     65                   168
#
#   product.specs.bus_unicode metadata.normal_price_usd  \
# 0       PCI Express 4.0 x16                   1411.99
# 0             Thunderbolt 3                   1032.15
# 0       PCI Express 4.0 x16                    583.71
# 0       PCI Express 4.0 x16                    446.07
# 0       PCI Express 3.0 x16                    296.35
#
#   metadata.offer_price_usd precio_normal_pesos_chilenos  \
# 0                  1411.99                    1148990.0
# 0                  1032.15                     839900.0
# 0                   577.46                     474990.0
# 0                   446.07                     362989.0
# 0                   286.33                     241155.0
#
#   precio_oferta_pesos_chilenos      conectores_de_video  \
# 0                    1148990.0  3x DisplayPort; 1x HDMI
# 0                     839900.0  3x DisplayPort; 2x HDMI
# 0                     469900.0  3x DisplayPort; 1x HDMI
# 0                     362989.0  3x DisplayPort; 1x HDMI
# 0                     233000.0                      NaN
#
#                               link_tarjeta fecha_obtencion_info  \
# 0  https://www.solotodo.cl/products/190276           10/04/2023
# 0  https://www.solotodo.cl/products/114051           10/04/2023
# 0  https://www.solotodo.cl/products/144243           10/04/2023
# 0  https://www.solotodo.cl/products/179024           10/04/2023
# 0   https://www.solotodo.cl/products/72746           10/04/2023
#
#   resolucion_maxima_soportada
# 0                          4K
# 0                          4K
# 0                       1440p
# 0                       1440p
# 0                         NaN

# %% [markdown]
# ### Creacion del dataframe que contenga solo informacion de las tarjetas que queremos
#
# En particular se definió la siguiente lista de tarjetas a analizar:

# %% [markdown]
# | Nvidia              | AMD                |
# |---------------------|--------------------|
# | RTX 3050    | RX 6500 XT  |
# | RTX 3060    | RX 6600     |
# | RTX 3060 Ti | RX 6600 XT  |
# | RTX 3070    | RX 6650 XT  |
# | RTX 3070 Ti | RX 6700 XT  |
# | RTX 3080    | RX 6750 XT  |
# | RTX 3080 Ti | RX 6800     |
# | RTX 3090    | RX 6800 XT  |
# | RTX 3090 Ti | RX 6900 XT  |
# | RTX 4090    | RX 7900 XTX |
# | RTX 4080    | RX 7900 XT  |
# | RTX 4070 Ti |                    |

# %%
lista_tarjetas = ['RTX 3050', 'RTX 3060', 'RTX 3060 Ti', 'RTX 3070', 'RTX 3070 Ti', 'RTX 3080', 'RTX 3080 Ti',
                'RTX 3090', 'RTX 3090 Ti', 'RTX 4090', 'RTX 4080', 'RTX 4070 Ti', 'RX 6500 XT', 'RX 6600', 
                'RX 6600 XT', 'RX 6650 XT', 'RX 6700 XT', 'RX 6750 XT', 'RX 6800', 'RX 6800 XT',
                'RX 6900 XT', 'RX 7900 XTX', 'RX 7900 XT']

# %%
df7 = df6.loc[df5['product.specs.gpu_name'].isin(lista_tarjetas)]
df7
# Out:
#    product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                             AMD            RX 7900 XTX
# 0                                          NVIDIA               RTX 3080
# 0                                          NVIDIA            RTX 3060 Ti
# 0                                          NVIDIA               RTX 3060
# 0                                             AMD             RX 6600 XT
# ..                                            ...                    ...
# 0                                          NVIDIA            RTX 3060 Ti
# 0                                          NVIDIA            RTX 4070 Ti
# 0                                          NVIDIA               RTX 3050
# 0                                          NVIDIA            RTX 4070 Ti
# 0                                          NVIDIA               RTX 4080
#
#    product.brand_name  product.specs.gpu_stream_processors  \
# 0              ASRock                                 6144
# 0            Gigabyte                                 8704
# 0                 PNY                                 4664
# 0                ASUS                                 3584
# 0              ASRock                                 2048
# ..                ...                                  ...
# 0                 PNY                                 4664
# 0                 MSI                                 7680
# 0               Palit                                 2560
# 0            Gigabyte                                 7680
# 0                 MSI                                 9728
#
#      product.specs.gpu_unicode  product.specs.core_clock  \
# 0       AMD Radeon RX 7900 XTX                      2615
# 0      NVIDIA GeForce RTX 3080                      1710
# 0   NVIDIA GeForce RTX 3060 Ti                      1665
# 0      NVIDIA GeForce RTX 3060                      1867
# 0        AMD Radeon RX 6600 XT                      2593
# ..                         ...                       ...
# 0   NVIDIA GeForce RTX 3060 Ti                      1665
# 0   NVIDIA GeForce RTX 4070 Ti                      2760
# 0      NVIDIA GeForce RTX 3050                      1777
# 0   NVIDIA GeForce RTX 4070 Ti                      2625
# 0      NVIDIA GeForce RTX 4080                      2520
#
#     product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                 24576                                   320
# 0                                 10240                                   320
# 0                                  8192                                   256
# 0                                  8192                                   128
# 0                                  8192                                   128
# ..                                  ...                                   ...
# 0                                  8192                                   256
# 0                                 12288                                   192
# 0                                  8192                                   128
# 0                                 12288                                   192
# 0                                 16384                                   256
#
#    product.specs.memory_type_name  product.specs.gpu_tdp  \
# 0                           GDDR6                    355
# 0                          GDDR6X                    320
# 0                           GDDR6                    200
# 0                           GDDR6                    170
# 0                           GDDR6                    160
# ..                            ...                    ...
# 0                          GDDR6X                    200
# 0                          GDDR6X                    285
# 0                           GDDR6                    130
# 0                          GDDR6X                    285
# 0                          GDDR6X                    320
#
#     product.specs.length product.specs.bus_unicode metadata.normal_price_usd  \
# 0                    330       PCI Express 4.0 x16                   1411.99
# 0                    300             Thunderbolt 3                   1032.15
# 0                    251       PCI Express 4.0 x16                    583.71
# 0                    200       PCI Express 4.0 x16                    446.07
# 0                    269        PCI Express 4.0 x8         651.1800000000001
# ..                   ...                       ...                       ...
# 0                    250       PCI Express 4.0 x16                     616.4
# 0                    337       PCI Express 4.0 x16                   1278.04
# 0                    172        PCI Express 4.0 x8                    413.88
# 0                    301       PCI Express 4.0 x16                    1335.8
# 0                    322       PCI Express 4.0 x16        1623.1100000000001
#
#    metadata.offer_price_usd precio_normal_pesos_chilenos  \
# 0                   1411.99                    1148990.0
# 0                   1032.15                     839900.0
# 0                    577.46                     474990.0
# 0                    446.07                     362989.0
# 0                    614.32                     529894.0
# ..                      ...                          ...
# 0                    589.86                     501590.0
# 0                   1228.88                    1039990.0
# 0                    393.23                     336790.0
# 0                    1335.8                    1086990.0
# 0                   1560.68                    1320790.0
#
#    precio_oferta_pesos_chilenos                conectores_de_video  \
# 0                     1148990.0            3x DisplayPort; 1x HDMI
# 0                      839900.0            3x DisplayPort; 2x HDMI
# 0                      469900.0            3x DisplayPort; 1x HDMI
# 0                      362989.0            3x DisplayPort; 1x HDMI
# 0                      499900.0        3x DisplayPort; 1x HDMI 2.1
# ..                          ...                                ...
# 0                      479990.0  3x Display Port 1.4a; 1x HDMI 2.1
# 0                      999990.0            3x DisplayPort; 1x HDMI
# 0                      319990.0       1x Display Port 1.4a; 1x DVI
# 0                     1086990.0        3x DisplayPort; 1x HDMI 2.1
# 0                     1269990.0  3x Display Port 1.4a; 1x HDMI 2.1
#
#                                link_tarjeta fecha_obtencion_info  \
# 0   https://www.solotodo.cl/products/190276           10/04/2023
# 0   https://www.solotodo.cl/products/114051           10/04/2023
# 0   https://www.solotodo.cl/products/144243           10/04/2023
# 0   https://www.solotodo.cl/products/179024           10/04/2023
# 0   https://www.solotodo.cl/products/130428           10/04/2023
# ..                                      ...                  ...
# 0   https://www.solotodo.cl/products/192193           10/04/2023
# 0   https://www.solotodo.cl/products/192769           10/04/2023
# 0   https://www.solotodo.cl/products/183117           10/04/2023
# 0   https://www.solotodo.cl/products/196249           10/04/2023
# 0   https://www.solotodo.cl/products/195228           10/04/2023
#
#    resolucion_maxima_soportada
# 0                           4K
# 0                           4K
# 0                        1440p
# 0                        1440p
# 0                        1440p
# ..                         ...
# 0                        1440p
# 0                           8K
# 0                        1080p
# 0                           8K
# 0                           8K
#
# [238 rows x 20 columns]

# %% [markdown]
# ### Creación del dataframe final

# %%
df7 = df7.reset_index(drop=True)
df7
# Out:
#     product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                              AMD            RX 7900 XTX
# 1                                           NVIDIA               RTX 3080
# 2                                           NVIDIA            RTX 3060 Ti
# 3                                           NVIDIA               RTX 3060
# 4                                              AMD             RX 6600 XT
# ..                                             ...                    ...
# 233                                         NVIDIA            RTX 3060 Ti
# 234                                         NVIDIA            RTX 4070 Ti
# 235                                         NVIDIA               RTX 3050
# 236                                         NVIDIA            RTX 4070 Ti
# 237                                         NVIDIA               RTX 4080
#
#     product.brand_name  product.specs.gpu_stream_processors  \
# 0               ASRock                                 6144
# 1             Gigabyte                                 8704
# 2                  PNY                                 4664
# 3                 ASUS                                 3584
# 4               ASRock                                 2048
# ..                 ...                                  ...
# 233                PNY                                 4664
# 234                MSI                                 7680
# 235              Palit                                 2560
# 236           Gigabyte                                 7680
# 237                MSI                                 9728
#
#       product.specs.gpu_unicode  product.specs.core_clock  \
# 0        AMD Radeon RX 7900 XTX                      2615
# 1       NVIDIA GeForce RTX 3080                      1710
# 2    NVIDIA GeForce RTX 3060 Ti                      1665
# 3       NVIDIA GeForce RTX 3060                      1867
# 4         AMD Radeon RX 6600 XT                      2593
# ..                          ...                       ...
# 233  NVIDIA GeForce RTX 3060 Ti                      1665
# 234  NVIDIA GeForce RTX 4070 Ti                      2760
# 235     NVIDIA GeForce RTX 3050                      1777
# 236  NVIDIA GeForce RTX 4070 Ti                      2625
# 237     NVIDIA GeForce RTX 4080                      2520
#
#      product.specs.memory_quantity_value  \
# 0                                  24576
# 1                                  10240
# 2                                   8192
# 3                                   8192
# 4                                   8192
# ..                                   ...
# 233                                 8192
# 234                                12288
# 235                                 8192
# 236                                12288
# 237                                16384
#
#      product.specs.memory_bus_width_value product.specs.memory_type_name  \
# 0                                     320                          GDDR6
# 1                                     320                         GDDR6X
# 2                                     256                          GDDR6
# 3                                     128                          GDDR6
# 4                                     128                          GDDR6
# ..                                    ...                            ...
# 233                                   256                         GDDR6X
# 234                                   192                         GDDR6X
# 235                                   128                          GDDR6
# 236                                   192                         GDDR6X
# 237                                   256                         GDDR6X
#
#      product.specs.gpu_tdp  product.specs.length product.specs.bus_unicode  \
# 0                      355                   330       PCI Express 4.0 x16
# 1                      320                   300             Thunderbolt 3
# 2                      200                   251       PCI Express 4.0 x16
# 3                      170                   200       PCI Express 4.0 x16
# 4                      160                   269        PCI Express 4.0 x8
# ..                     ...                   ...                       ...
# 233                    200                   250       PCI Express 4.0 x16
# 234                    285                   337       PCI Express 4.0 x16
# 235                    130                   172        PCI Express 4.0 x8
# 236                    285                   301       PCI Express 4.0 x16
# 237                    320                   322       PCI Express 4.0 x16
#
#     metadata.normal_price_usd metadata.offer_price_usd  \
# 0                     1411.99                  1411.99
# 1                     1032.15                  1032.15
# 2                      583.71                   577.46
# 3                      446.07                   446.07
# 4           651.1800000000001                   614.32
# ..                        ...                      ...
# 233                     616.4                   589.86
# 234                   1278.04                  1228.88
# 235                    413.88                   393.23
# 236                    1335.8                   1335.8
# 237        1623.1100000000001                  1560.68
#
#     precio_normal_pesos_chilenos precio_oferta_pesos_chilenos  \
# 0                      1148990.0                    1148990.0
# 1                       839900.0                     839900.0
# 2                       474990.0                     469900.0
# 3                       362989.0                     362989.0
# 4                       529894.0                     499900.0
# ..                           ...                          ...
# 233                     501590.0                     479990.0
# 234                    1039990.0                     999990.0
# 235                     336790.0                     319990.0
# 236                    1086990.0                    1086990.0
# 237                    1320790.0                    1269990.0
#
#                    conectores_de_video  \
# 0              3x DisplayPort; 1x HDMI
# 1              3x DisplayPort; 2x HDMI
# 2              3x DisplayPort; 1x HDMI
# 3              3x DisplayPort; 1x HDMI
# 4          3x DisplayPort; 1x HDMI 2.1
# ..                                 ...
# 233  3x Display Port 1.4a; 1x HDMI 2.1
# 234            3x DisplayPort; 1x HDMI
# 235       1x Display Port 1.4a; 1x DVI
# 236        3x DisplayPort; 1x HDMI 2.1
# 237  3x Display Port 1.4a; 1x HDMI 2.1
#
#                                 link_tarjeta fecha_obtencion_info  \
# 0    https://www.solotodo.cl/products/190276           10/04/2023
# 1    https://www.solotodo.cl/products/114051           10/04/2023
# 2    https://www.solotodo.cl/products/144243           10/04/2023
# 3    https://www.solotodo.cl/products/179024           10/04/2023
# 4    https://www.solotodo.cl/products/130428           10/04/2023
# ..                                       ...                  ...
# 233  https://www.solotodo.cl/products/192193           10/04/2023
# 234  https://www.solotodo.cl/products/192769           10/04/2023
# 235  https://www.solotodo.cl/products/183117           10/04/2023
# 236  https://www.solotodo.cl/products/196249           10/04/2023
# 237  https://www.solotodo.cl/products/195228           10/04/2023
#
#     resolucion_maxima_soportada
# 0                            4K
# 1                            4K
# 2                         1440p
# 3                         1440p
# 4                         1440p
# ..                          ...
# 233                       1440p
# 234                          8K
# 235                       1080p
# 236                          8K
# 237                          8K
#
# [238 rows x 20 columns]

# %% [markdown]
# ### Formateamos las columnas del dataframe a sus valores correspondientes

# %%
df7['metadata.normal_price_usd'] = df7['metadata.normal_price_usd'].astype('float')
df7['metadata.offer_price_usd'] = df7['metadata.offer_price_usd'].astype('float')
df7['precio_normal_pesos_chilenos'] = df7['precio_normal_pesos_chilenos'].astype('float')
df7['precio_oferta_pesos_chilenos'] = df7['precio_oferta_pesos_chilenos'].astype('float')

# %% [markdown]
# ### Exportamos el dataframe a csv

# %%
df7['fecha_obtencion_info'] = pd.to_datetime(df7['fecha_obtencion_info'], format="%d/%m/%Y")

# %%
path = f'Data/gpu-data-{datetime.datetime.now().strftime("%d-%m-%Y")}.csv'
df7.to_csv(path, decimal=',', sep=';', index=False, date_format="%d-%m-%Y")

# %%
df7.head()
# Out:
#   product.specs.gpu_line_family_brand_brand_name product.specs.gpu_name  \
# 0                                            AMD            RX 7900 XTX
# 1                                         NVIDIA               RTX 3080
# 2                                         NVIDIA            RTX 3060 Ti
# 3                                         NVIDIA               RTX 3060
# 4                                            AMD             RX 6600 XT
#
#   product.brand_name  product.specs.gpu_stream_processors  \
# 0             ASRock                                 6144
# 1           Gigabyte                                 8704
# 2                PNY                                 4664
# 3               ASUS                                 3584
# 4             ASRock                                 2048
#
#     product.specs.gpu_unicode  product.specs.core_clock  \
# 0      AMD Radeon RX 7900 XTX                      2615
# 1     NVIDIA GeForce RTX 3080                      1710
# 2  NVIDIA GeForce RTX 3060 Ti                      1665
# 3     NVIDIA GeForce RTX 3060                      1867
# 4       AMD Radeon RX 6600 XT                      2593
#
#    product.specs.memory_quantity_value  product.specs.memory_bus_width_value  \
# 0                                24576                                   320
# 1                                10240                                   320
# 2                                 8192                                   256
# 3                                 8192                                   128
# 4                                 8192                                   128
#
#   product.specs.memory_type_name  product.specs.gpu_tdp  product.specs.length  \
# 0                          GDDR6                    355                   330
# 1                         GDDR6X                    320                   300
# 2                          GDDR6                    200                   251
# 3                          GDDR6                    170                   200
# 4                          GDDR6                    160                   269
#
#   product.specs.bus_unicode  metadata.normal_price_usd  \
# 0       PCI Express 4.0 x16                    1411.99
# 1             Thunderbolt 3                    1032.15
# 2       PCI Express 4.0 x16                     583.71
# 3       PCI Express 4.0 x16                     446.07
# 4        PCI Express 4.0 x8                     651.18
#
#    metadata.offer_price_usd  precio_normal_pesos_chilenos  \
# 0                   1411.99                     1148990.0
# 1                   1032.15                      839900.0
# 2                    577.46                      474990.0
# 3                    446.07                      362989.0
# 4                    614.32                      529894.0
#
#    precio_oferta_pesos_chilenos          conectores_de_video  \
# 0                     1148990.0      3x DisplayPort; 1x HDMI
# 1                      839900.0      3x DisplayPort; 2x HDMI
# 2                      469900.0      3x DisplayPort; 1x HDMI
# 3                      362989.0      3x DisplayPort; 1x HDMI
# 4                      499900.0  3x DisplayPort; 1x HDMI 2.1
#
#                               link_tarjeta fecha_obtencion_info  \
# 0  https://www.solotodo.cl/products/190276           10/04/2023
# 1  https://www.solotodo.cl/products/114051           10/04/2023
# 2  https://www.solotodo.cl/products/144243           10/04/2023
# 3  https://www.solotodo.cl/products/179024           10/04/2023
# 4  https://www.solotodo.cl/products/130428           10/04/2023
#
#   resolucion_maxima_soportada
# 0                          4K
# 1                          4K
# 2                       1440p
# 3                       1440p
# 4                       1440p

# %% [markdown]
# # Iteraciones para recopilar datos y ponerlos en una BBDD

# %%
# !pip install ipython-sql
# !pip install sqlalchemy==1.3.24 #%load_ext sql es compatible con esta version de sqlalchemy.

# %%
# Una vez ejecutado el codigo de arriba y obtenido los datos en un dataframe, vamos a conectarnos
# a la BBDD y subir los datos.

# Creamos la conexion a SQL Server
import pyodbc

try:
    conn = pyodbc.connect(Trusted_Connection='yes', 
                          driver = '{SQL Server}',
                          server = 'PC-JOSALO\SQLEXPRESSSERVER', 
                          database = 'GPU_DATABASE')
    cur = conn.cursor()

    for index, row in df7.iterrows():    
        cur.execute('''INSERT INTO dbo.gpu_data 
                        (product_specs_gpu_line_family_brand_brand_name,
                         product_specs_gpu_name,
                         product_brand_name,
                         product_specs_gpu_stream_processors,
                         product_specs_gpu_unicode,
                         product_specs_core_clock,
                         product_specs_memory_quantity_value,
                         product_specs_memory_bus_width_value,
                         product_specs_memory_type_name,
                         product_specs_gpu_tdp,
                         product_specs_length,
                         product_specs_bus_unicode,
                         metadata_normal_price_usd,
                         metadata_offer_price_usd,
                         precio_normal_pesos_chilenos,
                         precio_oferta_pesos_chilenos,
                         conectores_de_video,
                         link_tarjeta,
                         fecha_obtencion_info,
                         resolucion_maxima_soportada) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)''',
                                                                          row['product.specs.gpu_line_family_brand_brand_name'],
                                                                          row['product.specs.gpu_name'], 
                                                                          row['product.brand_name'], 
                                                                          row['product.specs.gpu_stream_processors'],
                                                                          row['product.specs.gpu_unicode'],
                                                                          row['product.specs.core_clock'],
                                                                          row['product.specs.memory_quantity_value'],
                                                                          row['product.specs.memory_bus_width_value'],
                                                                          row['product.specs.memory_type_name'],
                                                                          row['product.specs.gpu_tdp'],
                                                                          row['product.specs.length'],
                                                                          row['product.specs.bus_unicode'],
                                                                          row['metadata.normal_price_usd'],
                                                                          row['metadata.offer_price_usd'],
                                                                          row['precio_normal_pesos_chilenos'],
                                                                          row['precio_oferta_pesos_chilenos'],
                                                                          row['conectores_de_video'],
                                                                          row['link_tarjeta'],
                                                                          row['fecha_obtencion_info'],
                                                                          row['resolucion_maxima_soportada'])

    conn.commit()
    cur.close()
    print('|-------------------Datos guardados exitosamente en la base de datos-------------------|')
    print(f'{len(df7)} datos nuevos recolectados')

except Exception as e:
    print(e)
# Out:
# |-------------------Datos guardados exitosamente en la base de datos-------------------|
# 238 datos nuevos recolectados

# %%
df7.dtypes
# Out:
# product.specs.gpu_line_family_brand_brand_name            object
# product.specs.gpu_name                                    object
# product.brand_name                                        object
# product.specs.gpu_stream_processors                        int64
# product.specs.gpu_unicode                                 object
# product.specs.core_clock                                   int64
# product.specs.memory_quantity_value                        int64
# product.specs.memory_bus_width_value                       int64
# product.specs.memory_type_name                            object
# product.specs.gpu_tdp                                      int64
# product.specs.length                                       int64
# product.specs.bus_unicode                                 object
# metadata.normal_price_usd                                float64
# metadata.offer_price_usd                                 float64
# precio_normal_pesos_chilenos                             float64
# precio_oferta_pesos_chilenos                             float64
# conectores_de_video                                       object
# link_tarjeta                                              object
# fecha_obtencion_info                              datetime64[ns]
# resolucion_maxima_soportada                               object
# dtype: object
